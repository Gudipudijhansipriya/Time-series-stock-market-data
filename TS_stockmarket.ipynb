# %%
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Google stock data

# %%
### 1 Google stock
g_stock=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\Timeseries_lab\\GOOG Stock data.csv") 
g_stock
# Out:
#            Date        Open        High         Low       Close    AdjClose  \
# 0    25-02-2013  399.652008  402.695587  393.769043  393.908539  393.908539
# 1    26-02-2013  396.015625  396.488861  390.735443  393.589722  393.589722
# 2    27-02-2013  395.916016  400.872437  394.077911  398.396698  398.396698
# 3    28-02-2013  399.054260  401.988251  399.019379  399.104065  399.104065
# 4    01-03-2013  397.410400  402.062958  396.588501  401.589752  401.589752
# ..          ...         ...         ...         ...         ...         ...
# 995  06-02-2017  799.700012  801.669983  795.250000  801.340027  801.340027
# 996  07-02-2017  803.989990  810.500000  801.780029  806.969971  806.969971
# 997  08-02-2017  807.000000  811.840027  803.190002  808.380005  808.380005
# 998  09-02-2017  809.510010  810.659973  804.539978  809.559998  809.559998
# 999  10-02-2017  811.700012  815.250000  809.780029  813.669983  813.669983
#
#       Volume
# 0    4625071
# 1    4421511
# ...

# %%
fig, ax = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle('\nDistribution\n', color='blue', fontsize=20)

# Title of each Distribution
ax[0,0].set_title('Open price distribution', color='blue')
ax[0,1].set_title('High price distribution', color='blue')
ax[0,2].set_title('Low price distribution', color='blue')
ax[1,0].set_title('Close price distribution', color='blue')
ax[1,1].set_title('Adjacent Close price distribution', color='blue')
ax[1,2].set_title('Volume price distribution', color='blue')

sns.kdeplot(ax=ax[0,0], x=g_stock.Open, shade=True, color='green')
sns.kdeplot(ax=ax[0,1], x=g_stock.High, shade=True, color='blue')
sns.kdeplot(ax=ax[0,2], x=g_stock.Low, shade=True, color='red')
sns.kdeplot(ax=ax[1,0], x=g_stock.Close, shade=True, color='magenta')
sns.kdeplot(ax=ax[1,1], x=g_stock.AdjClose, shade=True, color='purple')
sns.kdeplot(ax=ax[1,2], x=g_stock.Volume, shade=True, color='black')

plt.show()

# %% [markdown]
# * Conclusion:  We remark that *Open Price, High price, Low price, Close price* and
#
# * Adjacent price* have the same distribution and *Volume* distribution is different.
#
# * Therefore the analysis will be based on Volume and the open price values

# %%
plt.plot(g_stock.Date,g_stock.Open)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Open")
plt.title("plot for date and open")
plt.show()

# %% [markdown]
# * Interpretation : There is exponential trend in the serie

# %%
plt.plot(g_stock.Date,g_stock.High)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("High")
plt.title("plot fot date and high")
plt.show()

# %%
plt.plot(g_stock.Date,g_stock.Low)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Low")
plt.title("plot for date and low")
plt.show()

# %%
plt.plot(g_stock.Date,g_stock.Close)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Close")
plt.title("plot for date and close")
plt.show()

# %%
plt.plot(g_stock.Date,g_stock.AdjClose)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("AdjClose")
plt.title("plot for date and adjclose")
plt.show()

# %%
plt.plot(g_stock.Date,g_stock.Volume)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Volume")
plt.title("plot for date and volume")
plt.show()

# %% [markdown]
# * Interpretation: We can find a stationnarity and Unexpected event

# %%
rol=g_stock.rolling(window=7).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### stock data

# %%
s_data=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\Stock_Data.csv")
s_data
# Out:
#            DATE      Cost
# 0    01-01-1985   72.5052
# 1    02-01-1985   70.6720
# 2    03-01-1985   62.4502
# 3    04-01-1985   57.4714
# 4    05-01-1985   55.3151
# ..          ...       ...
# 392  09-01-2017   98.6154
# 393  10-01-2017   93.6137
# 394  11-01-2017   97.3359
# 395  12-01-2017  114.7212
# 396  01-01-2018  129.4048
#
# [397 rows x 2 columns]

# %%
plt.plot(s_data.DATE,s_data.Cost)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Cost")
plt.title("plot for date and Cost")
plt.show()

# %% [markdown]
# * Interpretation : Positive trend

# %%
rol=s_data.rolling(window=7).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Beer sales

# %%
Beer=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\beer_sales.csv")
Beer
# Out:
#            Date  Beer_Sale
# 0    01-01-1963        591
# 1    02-01-1963        464
# 2    03-01-1963        461
# 3    04-01-1963        605
# 4    05-01-1963        586
# ..          ...        ...
# 703  08-01-2021        668
# 704  09-01-2021        725
# 705  10-01-2021        649
# 706  11-01-2021        725
# 707  12-01-2021        811
#
# [708 rows x 2 columns]

# %%
plt.plot(Beer.Date,Beer.Beer_Sale)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Date")
plt.ylabel("Beer_sales")
plt.title("plot for beer sales in 58 years")
plt.show()

# %% [markdown]
# * Interpretation : There an upward trend from 1963 to hardly 2005, and unexpected event occurs, Then after a trend again

# %%
rol=Beer.rolling(window=7).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Marker yield_1

# %%
market_1=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\Market_1.csv")
market_1
# Out:
#       Month  Rate
# 0    Apr-53  2.83
# 1    May-53  3.05
# 2    Jun-53  3.11
# 3    Jul-53  2.93
# 4    Aug-53  2.95
# ..      ...   ...
# 151  Aug-96  6.64
# 152  Sep-96  6.83
# 153  Oct-96  6.53
# 154  Nov-96  6.20
# 155  Dec-96  6.30
#
# [156 rows x 2 columns]

# %%
plt.plot(market_1.Month,market_1.Rate)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Month")
plt.ylabel("Rate in percentage")
plt.title("plot for market_1 yield on US treasury securities at 10 year constant maturity")
plt.show()

# %% [markdown]
# * Interpretation : Trend + Unexpected event

# %%
rol=market_1.rolling(window=6).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * Market yield_2

# %%
market_2=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\Market_2.csv")
market_2
# Out:
#       Month  Rate
# 0    Jul-56  3.11
# 1    Aug-56  3.33
# 2    Sep-56  3.38
# 3    Oct-56  3.34
# 4    Nov-56  3.49
# ..      ...   ...
# 159  Jan-00  6.66
# 160  Feb-00  6.52
# 161  Mar-00  6.26
# 162  Apr-00  5.99
# 163  May-00  6.44
#
# [164 rows x 2 columns]

# %%
plt.plot(market_2.Month,market_2.Rate)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Month")
plt.ylabel("Rate in percentage")
plt.title("plot for market_2 yield on US treasury securities at 10 year constant maturity ")
plt.show()

# %% [markdown]
# * Interpretation: Cyclic + Trend

# %%
rol=market_2.rolling(window=6).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * chemical Process Viscosity

# %%
chemical=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\chemical_viscosity.csv")
chemical

# %%
plt.plot(chemical.Time_period,chemical.Reading)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("Time_period")
plt.ylabel("Readings")
plt.title("plot for chemical reading in particular time period ")
plt.show()

# %% [markdown]
# * Interpretation : Stationarity + Seasonality

# %%
rol=chemical.rolling(window=7).mean()

rol.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# * pharmaceutical product sales

# %%
pharma=pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Desktop\\pharma_sale.csv")
pharma
# Out:
#      week    sales
# 0       1  10618.1
# 1       2  10537.9
# 2       3  10209.3
# 3       4  10553.0
# 4       5   9934.9
# ..    ...      ...
# 115   116  10650.0
# 116   117  10741.6
# 117   118  10246.0
# 118   119  10354.4
# 119   120  10155.4
#
# [120 rows x 2 columns]

# %%
plt.plot(pharma.week,pharma.sales)
plt.rcParams["figure.figsize"] = [20,9]
plt.rcParams["figure.autolayout"] = True
plt.xlabel("week")
plt.ylabel("sales")
plt.title("plot for pharmaceutical products sales in a week")
plt.show()

# %% [markdown]
# * Interpretation : Seasonality + Stationnarity + Cyclic movement

# %%
rol=pharma .rolling(window=4).mean()

rol.plot()
# Out:
# <AxesSubplot:>
